# %%
from neuprint import Client
c=Client('neuprint.janelia.org', dataset='hemibrain:v1.0.1', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Im1hdHRjaHVyZ2luQGdtYWlsLmNvbSIsImxldmVsIjoibm9hdXRoIiwiaW1hZ2UtdXJsIjoiaHR0cHM6Ly9saDMuZ29vZ2xldXNlcmNvbnRlbnQuY29tL2EtL0FBdUU3bUI4X3BlM2pfWEtUeVdWdEhtMkxIaFFjT080ci1CRWpxOHdna0JrP3N6PTUwP3N6PTUwIiwiZXhwIjoxNzYxNTM2MDcyfQ.4n6x5PHAL9-dnOddaxvJceVwYGT21E2rD2uEixJyefg')
c.fetch_version()
# Out:
# '0.1.0'

# %%
q = '''\
    MATCH (n :Neuron {'AL(L)': true})
    WHERE n.pre > 10
    RETURN n.bodyId AS bodyId, n.name AS name, n.pre AS numpre, n.post AS numpost
    ORDER BY n.pre + n.post DESC
'''

results = c.fetch_custom(q)

print(f"Found {len(results)} results")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in wrapper(*args, **kwargs)
#     213         try:
# --> 214             return f(*args, **kwargs)
#     215         except RequestException as ex:
#
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in _fetch(self, url, json, ispost)
#     361             r = self.session.get(url, verify=self.verify)
# --> 362         r.raise_for_status()
#     363         return r
#
# //anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://neuprint.janelia.org/api/custom/custom
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-16-272eeb2bd7ea> in <module>
#       6 '''
#       7
# ----> 8 results = c.fetch_custom(q)
#       9
#      10 print(f"Found {len(results)} results")
#
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in fetch_custom(self, cypher, dataset, format)
#     401         """
#     402         url = f"{self.server}/api/custom/custom"
# --> 403         return self._fetch_cypher(url, cypher, dataset, format)
#     404
#     405
#
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in _fetch_cypher(self, url, cypher, dataset, format)
#     426         result = self._fetch_json(url,
#     427                                   json={"cypher": cypher, "dataset": dataset},
# --> 428                                   ispost=True)
#     429
#     430         if format == 'json':
#
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in _fetch_json(self, url, json, ispost)
#     369
#     370     def _fetch_json(self, url, json=None, ispost=False):
# --> 371         r = self._fetch(url, json=json, ispost=ispost)
#     372         return ujson.loads(r.content)
#     373
#
# //anaconda3/lib/python3.7/site-packages/neuprint/client.py in wrapper(*args, **kwargs)
#     252             # mark it as already modified it doesn't get modified twice.
#     253             new_ex.response_content_appended = True
# --> 254             raise new_ex from ex
#     255     return wrapper
#     256
#
# HTTPError: Error accessing POST https://neuprint.janelia.org/api/custom/custom
#
# Cypher was:
#
#     MATCH (n :Neuron {'AL(L)': true})
#     WHERE n.pre > 10
#     RETURN n.bodyId AS bodyId, n.name AS name, n.pre AS numpre, n.post AS numpost
#     ORDER BY n.pre + n.post DESC
#
#
# Returned Error (400):
#
# Invalid input ''': expected whitespace, a property key name, '}', an identifier or UnsignedDecimalInteger (line 1, column 35 (offset: 34))
# "MATCH (n :`hemibrain_Neuron` {'AL(L)': true})"
#                                    ^

# %%
from neuprint import fetch_roi_hierarchy

print(fetch_roi_hierarchy(False, mark_primary=True, format='text'))
# Out:
# hemibrain
#  +-- AL(L)*
#  +-- AL(R)*
#  +-- AOT(R)
#  +-- CX
#  |   +-- AB(L)*
#  |   +-- AB(R)*
#  |   +-- EB*
#  |   +-- FB*
#  |   +-- NO*
#  |   +-- PB*
#  +-- GC
#  +-- GF(R)
#  +-- GNG*
#  +-- INP
#  |   +-- ATL(L)*
#  |   +-- ATL(R)*
#  |   +-- CRE(L)*
#  |   +-- CRE(R)*
#  |   +-- IB*
#  |   +-- ICL(L)*
#  |   +-- ICL(R)*
#  |   +-- SCL(L)*
#  |   +-- SCL(R)*
#  +-- LH(R)*
#  +-- LX(L)
#  |   +-- BU(L)*
#  |   +-- LAL(L)*
#  +-- LX(R)
#  |   +-- BU(R)*
#  |   +-- LAL(R)*
#  +-- MB(+ACA)(R)
#  |   +-- MB(R)
#  |   |   +-- CA(R)*
#  |   |   +-- PED(R)*
#  |   |   +-- a'L(R)*
#  |   |   +-- aL(R)*
#  |   |   +-- b'L(R)*
#  |   |   +-- bL(R)*
#  |   |   +-- gL(R)*
#  |   +-- dACA(R)
#  |   +-- lACA(R)
#  |   +-- vACA(R)
#  +-- MB(L)
#  |   +-- CA(L)*
#  |   +-- a'L(L)*
#  |   +-- aL(L)*
#  |   +-- b'L(L)*
#  |   +-- bL(L)*
#  |   +-- gL(L)*
#  +-- OL(R)
#  |   +-- AME(R)*
#  |   +-- LO(R)*
#  |   +-- LOP(R)*
#  |   +-- ME(R)*
#  +-- PENP
#  |   +-- CAN(R)*
#  |   +-- FLA(R)*
#  |   +-- PRW*
#  |   +-- SAD*
#  +-- POC
#  +-- SNP(L)
#  |   +-- SIP(L)*
#  |   +-- SMP(L)*
#  +-- SNP(R)
#  |   +-- SIP(R)*
#  |   +-- SLP(R)*
#  |   +-- SMP(R)*
#  +-- VLNP(R)
#  |   +-- AOTU(R)*
#  |   +-- AVLP(R)*
#  |   +-- PLP(R)*
#  |   +-- PVLP(R)*
#  |   +-- WED(R)*
#  +-- VMNP
#  |   +-- EPA(L)*
#  |   +-- EPA(R)*
#  |   +-- GOR(L)*
#  |   +-- GOR(R)*
#  |   +-- IPS(R)*
#  |   +-- SPS(L)*
#  |   +-- SPS(R)*
#  |   +-- VES(L)*
#  |   +-- VES(R)*
#  +-- mALT(L)
#  +-- mALT(R)

# %%
from neuprint import SegmentCriteria as SC
from neuprint import fetch_neurons

criteria = SC(outputRois=['AL(R)'],cropped=False)
neuron_df, roi_counts_df = fetch_neurons(criteria)

len(neuron_df)
# Out:
# 4870

# %%
from neuprint import fetch_adjacencies
# Out:
#           bodyId               instance                       type    pre  \
# 0      294792184         mlPN2(AVM04)_R  olfactory multi vPN mlALT     93
# 1      329566174     OA-VPM3(NO2/NO3)_R                    OA-VPM3   8568
# 2      329599710          mPNX(AVM06)_R  olfactory multi lvPN mALT    244
# 3      417199910          mPNX(AVM06)_R  olfactory multi lvPN mALT    162
# 4      425790257                  APL_R                        APL  16060
# 5      484130600    ADM10a_pct(ADM10)_R                 ADM10a_pct   2176
# 6      484821546    PVM09f_pct(PVM09)_R                 PVM09f_pct    504
# 7      488507414               Franken3                       None      7
# 8      488581156            (MBDLaxon2)                       None    920
# 9      508689623   PDM08og_pct(PDM08)_R                PDM08og_pct   1361
# 10     509626405          mPNX(AVM06)_R         VP multi lvPN mALT    206
# 11     542311358         mlPN2(AVM04)_R  olfactory multi vPN mlALT    147
# 12     542634818      mPN1_DM1(AVM02)_R                    DM1 lPN   4687
# 13     542665377         mlPN2(AVM04)_R  olfactory multi vPN mlALT    327
# 14     542751938    PVM09g_pct(PVM09)_R                 PVM09g_pct    182
# 15     544021095     mPN1_DA4l(AVM01)_R                  DA4l adPN   1382
# 16     546771021                   None                       None    591
# 17     549597974              (ADM08)_R                       None   2181
# 18     573333835      mPN1_DM4(AVM01)_R                   DM4 adPN   3652
# 19     573669915         mlPN2(AVM04)_R  olfactory multi vPN mlALT    124
# 20     574027813  ADL12b_b_pct(ADL12)_R               ADL12b_b_pct    189
# 21     574032862      mPN1_VA5(AVM02)_R                    VA5 lPN    800
# 22     574037266            mPN1_DA4m_R                  DA4m adPN   1530
# 23     574037281      mPN1_VA5(AVM02)_R                    VA5 lPN    827
# 24     574374051      mPN1_VA5(AVM02)_R                    VA5 lPN    854
# 25     577542489          mPNX(AVM06)_R  olfactory multi lvPN mALT    806
# 26     603785283                 mPNX_R            VP1l + VP3 C PN    693
# 27     604031203         mlPN2(AVM04)_R                    DM4 vPN    235
# 28     606090268      mPN1_VC1(AVM02)_R                    VC1 lPN   2358
# 29     609924156          mPNX(AVM06)_R  olfactory multi lvPN mALT    731
# ...          ...                    ...                        ...    ...
# 4840  5901201783                   None                       None      3
# 4841  5901202105                   None                       None      2
# 4842  5901202811                   None                       None      2
# 4843  5901202852                   None                       None      2
# 4844  5901203640                   None                       None      1
# 4845  5901204396                   None                       None      2
# 4846  5901204664                   None                       None      2
# 4847  5901204861                   None                       None     30
# 4848  5901204943                   None                       None      3
# 4849  5901205049                   None                       None      2
# 4850  5901205442                   None                       None      2
# 4851  5901206005                   None                       None    118
# 4852  5901206553                 LN(AL)               olfactory LN   3168
# 4853  5901206914                   None                       None      2
# 4854  5901207042                   None                       None      2
# 4855  5901207989                   None                       None      4
# 4856  5901208034                   None                       None      2
# 4857  5901208035                   None                       None      2
# 4858  5901208281                   None                       None      2
# 4859  5901210547                   None                       None      6
# 4860  5901211869                   None                       None      6
# 4861  5901217846                   None                       None      4
# 4862  5901218130                   None                       None      2
# 4863  5901218138                   None                       None      3
# 4864  5901218894            LN(AVM02)_R               olfactory LN   5916
# 4865  5901219227                   None                       None      2
# 4866  5901220862                   None                       None      2
# 4867  5901222037                   None                       None      2
# 4868  5901222731         mPN_R(AVM03)_R             VP1d + VP4 lPN   2113
# 4869  5901222910         mPN_R(AVM02)_R                    DM2 lPN   1953
#
#         post         size       status cropped      statusLabel cellBodyFiber  \
# 0        344    420662445       Traced   False   Roughly traced           A14
# 1       9998   6840451191       Traced   False           Traced          None
# 2        271    339385459       Traced   False   Roughly traced           A16
# 3        308    380278767       Traced   False   Roughly traced           A16
# 4     126513  23074962804       Traced   False   Roughly traced          None
# 5       3495   2418005080       Traced   False   Roughly traced          ABDL
# 6       2202   1429608250       Traced   False   Roughly traced          MEF1
# 7         10   4474031142  Unimportant    None      Unimportant          None
# 8        959   1168864681       Traced   False   Roughly traced          None
# 9       5609   5292610346       Traced   False   Roughly traced          pSM1
# 10       431    491985910       Traced   False   Roughly traced           A16
# 11        99    335750142       Traced   False   Roughly traced           A14
# 12     10437   8269988735       Traced   False   Roughly traced           A12
# 13       580    839465662       Traced   False   Roughly traced           A14
# 14       564   1663827804       Traced   False   Roughly traced          MEF1
# 15      1624   2308355531       Traced   False   Roughly traced           A11
# 16       813    737609396       Traced   False   Roughly traced          None
# 17      3144   2471283588       Traced   False   Roughly traced          None
# 18      7543   6049249020       Traced   False   Roughly traced           A11
# 19       248    419318308       Traced   False   Roughly traced           A14
# 20       535    594558788       Traced   False   Roughly traced        dAOTU1
# 21      2045   1681886064       Traced   False   Roughly traced           A12
# 22      2300   2237687473       Traced   False   Roughly traced          None
# 23      2063   1716659255       Traced   False   Roughly traced           A12
# 24      2138   1817310033       Traced   False   Roughly traced           A12
# 25      1684   1256071631       Traced   False   Roughly traced           A16
# 26      1362    998921705       Traced   False   Roughly traced          None
# 27       244    338812894       Traced   False   Roughly traced           A14
# 28      4481   3892810295       Traced   False   Roughly traced           A12
# 29       523   1122245853       Traced   False   Roughly traced           A16
# ...      ...          ...          ...     ...              ...           ...
# 4840       2      1546224       Assign    None        0.5assign          None
# 4841      13      1304566       Assign    None        0.5assign          None
# 4842       0       108652       Assign    None        0.5assign          None
# 4843       1      1483850       Assign    None        0.5assign          None
# 4844      13      2004732       Assign    None        0.5assign          None
# 4845       0      1149971       Assign    None        0.5assign          None
# 4846       1       682873       Assign    None        0.5assign          None
# 4847      42     33759438       Orphan    None  Orphan hotknife          None
# 4848       1      1204839       Assign    None        0.5assign          None
# 4849       3      1356287       Assign    None        0.5assign          None
# 4850       9      3017659       Assign    None        0.5assign          None
# 4851     159     95281057       Orphan    None  Orphan hotknife          None
# 4852   13884   4257696850       Traced   False   Roughly traced          None
# 4853       7       925780       Assign    None        0.5assign          None
# 4854       4       788216       Assign    None        0.5assign          None
# 4855       6      4624053       Assign    None        0.5assign          None
# 4856       3       616085       Assign    None        0.5assign          None
# 4857       4      1679212       Assign    None        0.5assign          None
# 4858       5      1429011       Assign    None        0.5assign          None
# 4859      44      8293890       Orphan    None  Orphan hotknife          None
# 4860       6      8686235       Orphan    None  Orphan hotknife          None
# 4861       1      4682612       Assign    None        0.5assign          None
# 4862       1       280614       Assign    None        0.5assign          None
# 4863      11      3631502       Assign    None        0.5assign          None
# 4864   20910   5852078180       Traced   False   Roughly traced           A12
# 4865       0      1607918       Assign    None        0.5assign          None
# 4866       2       546611       Assign    None        0.5assign          None
# 4867       2      1354673       Assign    None        0.5assign          None
# 4868    4087   2904336647       Traced   False   Roughly traced           A13
# 4869    4047   3617059565       Traced   False   Roughly traced           A12
#
#       somaRadius           somaLocation  \
# 0          336.5  [18923, 34319, 35424]
# 1            NaN                   None
# 2            NaN                   None
# 3          351.5  [13823, 33925, 34176]
# 4          900.1   [2995, 23785, 20800]
# 5          269.5   [18922, 31643, 7680]
# 6          376.0  [18129, 10881, 17840]
# 7            NaN                   None
# 8            NaN                   None
# 9          408.0   [20647, 15700, 7768]
# 10         381.5  [15431, 30739, 32600]
# 11         292.5  [20223, 34635, 33088]
# 12         832.0  [13135, 33944, 28560]
# 13         436.5  [19974, 34283, 33552]
# 14         321.0  [18875, 11698, 13136]
# 15         541.5  [22332, 35853, 22560]
# 16           NaN                   None
# 17         436.5  [21219, 36052, 20528]
# 18         496.5  [22929, 35392, 24800]
# 19         436.5  [17475, 30548, 33296]
# 20         292.5   [8691, 30150, 12176]
# 21         441.5  [15006, 36126, 29688]
# 22         246.5  [21164, 35177, 33424]
# 23         441.5  [14527, 35815, 29264]
# 24         391.5  [14032, 35651, 24688]
# 25           NaN                   None
# 26           NaN                   None
# 27           NaN                   None
# 28         616.5  [14585, 36529, 26792]
# 29         396.5  [14415, 28567, 31920]
# ...          ...                    ...
# 4840         NaN                   None
# 4841         NaN                   None
# 4842         NaN                   None
# 4843         NaN                   None
# 4844         NaN                   None
# 4845         NaN                   None
# 4846         NaN                   None
# 4847         NaN                   None
# 4848         NaN                   None
# 4849         NaN                   None
# 4850         NaN                   None
# 4851         NaN                   None
# 4852         NaN                   None
# 4853         NaN                   None
# 4854         NaN                   None
# 4855         NaN                   None
# 4856         NaN                   None
# 4857         NaN                   None
# 4858         NaN                   None
# 4859         NaN                   None
# 4860         NaN                   None
# 4861         NaN                   None
# 4862         NaN                   None
# 4863         NaN                   None
# 4864       651.5  [14105, 34608, 28648]
# 4865         NaN                   None
# 4866         NaN                   None
# 4867         NaN                   None
# 4868       516.5  [13856, 34548, 33512]
# 4869       501.5  [12564, 35025, 26256]
#
#                                               inputRois  \
# 0                [AL(R), LH(R), SIP(R), SLP(R), SNP(R)]
# 1     [AL(R), ATL(L), ATL(R), AVLP(R), BU(R), CA(R),...
# 2     [AL(R), ATL(R), INP, SIP(R), SLP(R), SMP(R), S...
# 3              [AL(R), SLP(R), SMP(R), SNP(R), mALT(R)]
# 4     [AL(R), ATL(L), ATL(R), AVLP(R), CA(R), CRE(-R...
# 5     [ATL(L), ATL(R), AVLP(R), CA(R), CRE(-ROB,-RUB...
# 6     [AL(R), AVLP(R), CRE(-ROB,-RUB)(R), CRE(R), FL...
# 7                                               [AL(R)]
# 8     [CRE(-ROB,-RUB)(R), CRE(L), CRE(R), FLA(R), IN...
# 9     [AL(R), AVLP(R), CRE(-ROB,-RUB)(R), CRE(R), GN...
# 10    [AL(R), MB(+ACA)(R), SLP(R), SMP(R), SNP(R), d...
# 11     [AL(R), AVLP(R), LH(R), SLP(R), SNP(R), VLNP(R)]
# 12    [AL(R), CA(R), ICL(R), INP, LH(R), MB(+ACA)(R)...
# 13          [AL(R), INP, LH(R), SCL(R), SLP(R), SNP(R)]
# 14    [AL(R), AVLP(R), CA(R), FLA(R), ICL(R), INP, L...
# 15    [AL(R), AL-DC3(R), CA(R), LH(R), MB(+ACA)(R), ...
# 16    [AL(R), AOTU(R), AVLP(R), GNG, LAL(-GA)(R), LA...
# 17    [AL(R), ATL(L), ATL(R), AVLP(R), CRE(-ROB,-RUB...
# 18    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), SLP(...
# 19    [AL(R), AMMC, INP, LH(R), PENP, SAD, SCL(R), S...
# 20    [AL(R), AVLP(R), ICL(R), INP, LH(R), PENP, PLP...
# 21    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 22    [AL(R), CA(R), ICL(R), INP, LH(R), MB(+ACA)(R)...
# 23    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 24    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 25    [AL(R), AL-DC3(R), AMMC, ATL(R), CRE(-ROB,-RUB...
# 26    [AL(R), INP, MB(+ACA)(R), PLP(R), SCL(R), SLP(...
# 27                                       [AL(R), LH(R)]
# 28    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), SLP(...
# 29    [AL(R), AVLP(R), INP, LH(R), SCL(R), SIP(R), S...
# ...                                                 ...
# 4840                                            [AL(R)]
# 4841                                            [AL(R)]
# 4842                                                 []
# 4843                                            [AL(R)]
# 4844                                            [AL(R)]
# 4845                                                 []
# 4846                                            [AL(R)]
# 4847                                            [AL(R)]
# 4848                                            [AL(R)]
# 4849                                            [AL(R)]
# 4850                                            [AL(R)]
# 4851                                            [AL(R)]
# 4852     [AL(R), AL-DC3(R), LAL(-GA)(R), LAL(R), LX(R)]
# 4853                                            [AL(R)]
# 4854                                            [AL(R)]
# 4855                [AL(R), LAL(-GA)(R), LAL(R), LX(R)]
# 4856                                            [AL(R)]
# 4857                                            [AL(R)]
# 4858                                            [AL(R)]
# 4859                                            [AL(R)]
# 4860                                            [AL(R)]
# 4861                                            [AL(R)]
# 4862                                            [AL(R)]
# 4863                                            [AL(R)]
# 4864                   [AL(R), AL-DC3(R), VES(R), VMNP]
# 4865                                                 []
# 4866                                            [AL(R)]
# 4867                                            [AL(R)]
# 4868  [AL(R), AVLP(R), GF(R), LH(R), PLP(R), PVLP(R)...
# 4869  [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
#
#                                              outputRois  \
# 0     [AL(R), LH(R), PLP(R), SIP(R), SLP(R), SNP(R),...
# 1     [AL(R), AOTU(R), ATL(L), ATL(R), AVLP(R), BU(L...
# 2      [AL(R), SIP(R), SLP(R), SMP(R), SNP(R), mALT(R)]
# 3                       [AL(R), SLP(R), SMP(R), SNP(R)]
# 4     [AL(R), ATL(L), CA(R), CRE(-ROB,-RUB)(R), CRE(...
# 5     [AL(R), ATL(L), ATL(R), BU(R), CA(R), CRE(-ROB...
# 6     [AL(R), AVLP(R), CRE(-ROB,-RUB)(R), CRE(R), FL...
# 7                                               [AL(R)]
# 8     [AL(R), CRE(-ROB,-RUB)(R), CRE(L), CRE(R), FLA...
# 9     [AL(R), AVLP(R), CRE(-ROB,-RUB)(R), CRE(R), GN...
# 10             [AL(R), SLP(R), SMP(R), SNP(R), mALT(R)]
# 11                       [AL(R), LH(R), SLP(R), SNP(R)]
# 12    [AL(R), CA(R), INP, LH(R), MB(+ACA)(R), MB(R),...
# 13                       [AL(R), LH(R), SLP(R), SNP(R)]
# 14    [AL(R), CX, FLA(R), INP, LH(R), MB(+ACA)(R), P...
# 15    [AL(R), AL-DC3(R), CA(R), LH(R), MB(+ACA)(R), ...
# 16    [AL(R), AOTU(R), AVLP(R), CRE(-ROB,-RUB)(R), C...
# 17    [AL(R), ATL(L), ATL(R), AVLP(R), BU(R), CRE(-R...
# 18    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), SLP(...
# 19          [AL(R), INP, LH(R), SCL(R), SLP(R), SNP(R)]
# 20    [AL(R), ICL(R), INP, LH(R), PENP, PLP(R), SAD,...
# 21    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 22    [AL(R), CA(R), INP, LH(R), MB(+ACA)(R), MB(R),...
# 23    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 24    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
# 25    [AL(R), AMMC, ATL(R), CRE(-ROB,-RUB)(R), CRE(R...
# 26    [AL(R), INP, LAL(-GA)(R), LAL(R), LX(R), MB(+A...
# 27                                       [AL(R), LH(R)]
# 28    [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), SLP(...
# 29    [AL(R), ATL(R), AVLP(R), INP, LH(R), SCL(R), S...
# ...                                                 ...
# 4840                                            [AL(R)]
# 4841                                            [AL(R)]
# 4842                                            [AL(R)]
# 4843                                            [AL(R)]
# 4844                                            [AL(R)]
# 4845                                            [AL(R)]
# 4846                                            [AL(R)]
# 4847                                            [AL(R)]
# 4848                                            [AL(R)]
# 4849                                            [AL(R)]
# 4850                                            [AL(R)]
# 4851                                            [AL(R)]
# 4852  [AL(R), AL-DC3(R), GNG, LAL(-GA)(R), LAL(R), L...
# 4853                                            [AL(R)]
# 4854                                            [AL(R)]
# 4855                                            [AL(R)]
# 4856                                            [AL(R)]
# 4857                                            [AL(R)]
# 4858                                            [AL(R)]
# 4859                                            [AL(R)]
# 4860                                            [AL(R)]
# 4861                                            [AL(R)]
# 4862                                            [AL(R)]
# 4863                                            [AL(R)]
# 4864     [AL(R), AL-DC3(R), LAL(-GA)(R), LAL(R), LX(R)]
# 4865                                            [AL(R)]
# 4866                                            [AL(R)]
# 4867                                            [AL(R)]
# 4868  [AL(R), AMMC, AVLP(R), LH(R), PENP, PLP(R), PV...
# 4869  [AL(R), CA(R), LH(R), MB(+ACA)(R), MB(R), mALT...
#
#                                                 roiInfo
# 0     {'SNP(R)': {'pre': 71, 'post': 155}, 'SLP(R)':...
# 1     {'SNP(R)': {'pre': 4239, 'post': 3328}, 'SMP(R...
# 2     {'SNP(R)': {'pre': 180, 'post': 93}, 'SIP(R)':...
# 3     {'SNP(R)': {'pre': 156, 'post': 91}, 'SLP(R)':...
# 4     {'MB(R)': {'pre': 15521, 'post': 122900}, 'aL(...
# 5     {'SNP(R)': {'pre': 687, 'post': 1993}, 'SMP(R)...
# 6     {'SNP(R)': {'pre': 207, 'post': 1583}, 'SMP(R)...
# 7                     {'AL(R)': {'pre': 7, 'post': 10}}
# 8     {'SNP(R)': {'pre': 688, 'post': 717}, 'SIP(R)'...
# 9     {'SNP(R)': {'pre': 331, 'post': 877}, 'SIP(R)'...
# 10    {'SNP(R)': {'pre': 198, 'post': 95}, 'SLP(R)':...
# 11    {'LH(R)': {'pre': 144, 'post': 37}, 'SNP(R)': ...
# 12    {'LH(R)': {'pre': 2274, 'post': 1448}, 'MB(R)'...
# 13    {'SNP(R)': {'pre': 22, 'post': 13}, 'SLP(R)': ...
# 14    {'SNP(R)': {'pre': 21, 'post': 237}, 'SMP(R)':...
# 15    {'SNP(R)': {'pre': 31, 'post': 19}, 'SLP(R)': ...
# 16    {'SNP(R)': {'pre': 498, 'post': 478}, 'SLP(R)'...
# 17    {'SNP(R)': {'pre': 728, 'post': 1796}, 'SMP(R)...
# 18    {'LH(R)': {'pre': 1545, 'post': 830}, 'MB(R)':...
# 19    {'LH(R)': {'pre': 118, 'post': 58}, 'INP': {'p...
# 20    {'LH(R)': {'pre': 3, 'post': 249}, 'SNP(R)': {...
# 21    {'LH(R)': {'pre': 330, 'post': 187}, 'mALT(R)'...
# 22    {'SNP(R)': {'pre': 33, 'post': 20}, 'SLP(R)': ...
# 23    {'LH(R)': {'pre': 321, 'post': 172}, 'MB(R)': ...
# 24    {'LH(R)': {'pre': 330, 'post': 197}, 'mALT(R)'...
# 25    {'SNP(R)': {'pre': 692, 'post': 152}, 'SIP(R)'...
# 26    {'SNP(R)': {'pre': 308, 'post': 122}, 'SLP(R)'...
# 27    {'LH(R)': {'pre': 234, 'post': 43}, 'AL(R)': {...
# 28    {'LH(R)': {'pre': 945, 'post': 477}, 'MB(R)': ...
# 29    {'SNP(R)': {'pre': 117, 'post': 45}, 'SIP(R)':...
# ...                                                 ...
# 4840                   {'AL(R)': {'pre': 3, 'post': 2}}
# 4841                  {'AL(R)': {'pre': 2, 'post': 13}}
# 4842                              {'AL(R)': {'pre': 2}}
# 4843                   {'AL(R)': {'pre': 2, 'post': 1}}
# 4844                  {'AL(R)': {'pre': 1, 'post': 13}}
# 4845                              {'AL(R)': {'pre': 2}}
# 4846                   {'AL(R)': {'pre': 2, 'post': 1}}
# 4847                 {'AL(R)': {'pre': 30, 'post': 42}}
# 4848                   {'AL(R)': {'pre': 3, 'post': 1}}
# 4849                   {'AL(R)': {'pre': 2, 'post': 3}}
# 4850                   {'AL(R)': {'pre': 2, 'post': 9}}
# 4851               {'AL(R)': {'pre': 118, 'post': 158}}
# 4852  {'AL(R)': {'pre': 3164, 'post': 13882}, 'LX(R)...
# 4853                   {'AL(R)': {'pre': 2, 'post': 7}}
# 4854                   {'AL(R)': {'pre': 2, 'post': 4}}
# 4855  {'AL(R)': {'pre': 4, 'post': 5}, 'LX(R)': {'po...
# 4856                   {'AL(R)': {'pre': 2, 'post': 3}}
# 4857                   {'AL(R)': {'pre': 2, 'post': 4}}
# 4858                   {'AL(R)': {'pre': 2, 'post': 5}}
# 4859                  {'AL(R)': {'pre': 6, 'post': 44}}
# 4860                   {'AL(R)': {'pre': 6, 'post': 6}}
# 4861                   {'AL(R)': {'pre': 4, 'post': 1}}
# 4862                   {'AL(R)': {'pre': 2, 'post': 1}}
# 4863                  {'AL(R)': {'pre': 3, 'post': 11}}
# 4864  {'AL(R)': {'pre': 5907, 'post': 20900}, 'LX(R)...
# 4865                              {'AL(R)': {'pre': 2}}
# 4866                   {'AL(R)': {'pre': 2, 'post': 2}}
# 4867                   {'AL(R)': {'pre': 2, 'post': 2}}
# 4868  {'LH(R)': {'pre': 729, 'post': 624}, 'VLNP(R)'...
# 4869  {'LH(R)': {'pre': 1049, 'post': 472}, 'MB(R)':...
#
# [4870 rows x 15 columns]
